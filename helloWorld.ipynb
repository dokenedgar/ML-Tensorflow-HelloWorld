# %% [markdown]
# <a href="https://colab.research.google.com/github/dokenedgar/ML-Tensorflow-HelloWorld/blob/main/helloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

model.fit(xs, ys, epochs=50)

print(model.predict([30.0]))
# Out:
# Epoch 1/50
# 1/1 [==============================] - 0s 1ms/step - loss: 47.4893
# Epoch 2/50
# 1/1 [==============================] - 0s 2ms/step - loss: 37.3636
# Epoch 3/50
# 1/1 [==============================] - 0s 2ms/step - loss: 29.3972
# Epoch 4/50
# 1/1 [==============================] - 0s 2ms/step - loss: 23.1296
# Epoch 5/50
# 1/1 [==============================] - 0s 2ms/step - loss: 18.1985
# Epoch 6/50
# 1/1 [==============================] - 0s 1ms/step - loss: 14.3189
# Epoch 7/50
# 1/1 [==============================] - 0s 1ms/step - loss: 11.2666
# Epoch 8/50
# 1/1 [==============================] - 0s 2ms/step - loss: 8.8652
# Epoch 9/50
# 1/1 [==============================] - 0s 1ms/step - loss: 6.9759
# Epoch 10/50
# 1/1 [==============================] - 0s 1ms/step - loss: 5.4894
# Epoch 11/50
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3199
# Epoch 12/50
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3998
# Epoch 13/50
# ...
